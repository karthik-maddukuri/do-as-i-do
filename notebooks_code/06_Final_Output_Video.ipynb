# %%
import cv2
import numpy as np
import os
from os.path import isfile, join

# %%
# %pwd
# Out:
# '/content/drive/My Drive/do-as-i-do/results/onlyfinalposes'

# %%
pathIn= './images/'
pathOut = 'video.mp4'

# %%
frame_array = []
files = [f for f in os.listdir(pathIn) if isfile(join(pathIn, f))]

# %%
files
# Out:
# ['pose000009_Synthesized_image.jpg',
#  'pose000071_Synthesized_image.jpg',
#  'pose000033_Synthesized_image.jpg',
#  'pose000186_Synthesized_image.jpg',
#  'pose000085_Synthesized_image.jpg',
#  'pose000130_Synthesized_image.jpg',
#  'pose000172_Synthesized_image.jpg',
#  'pose000025_Synthesized_image.jpg',
#  'pose000148_Synthesized_image.jpg',
#  'pose000093_Synthesized_image.jpg',
#  'pose000126_Synthesized_image.jpg',
#  'pose000220_Synthesized_image.jpg',
#  'pose000190_Synthesized_image.jpg',
#  'pose000106_Synthesized_image.jpg',
#  'pose000110_Synthesized_image.jpg',
#  'pose000242_Synthesized_image.jpg',
#  'pose000029_Synthesized_image.jpg',
#  'pose000005_Synthesized_image.jpg',
#  'pose000168_Synthesized_image.jpg',
#  'pose000013_Synthesized_image.jpg',
#  'pose000144_Synthesized_image.jpg',
#  'pose000097_Synthesized_image.jpg',
#  'pose000047_Synthesized_image.jpg',
#  'pose000216_Synthesized_image.jpg',
#  'pose000041_Synthesized_image.jpg',
#  'pose000142_Synthesized_image.jpg',
#  'pose000099_Synthesized_image.jpg',
#  'pose000089_Synthesized_image.jpg',
#  'pose000200_Synthesized_image.jpg',
#  'pose000051_Synthesized_image.jpg',
#  'pose000152_Synthesized_image.jpg',
#  'pose000210_Synthesized_image.jpg',
#  'pose000057_Synthesized_image.jpg',
#  'pose000039_Synthesized_image.jpg',
#  'pose000244_Synthesized_image.jpg',
#  'pose000003_Synthesized_image.jpg',
#  'pose000015_Synthesized_image.jpg',
#  'pose000116_Synthesized_image.jpg',
#  'pose000206_Synthesized_image.jpg',
#  'pose000178_Synthesized_image.jpg',
#  'pose000154_Synthesized_image.jpg',
#  'pose000100_Synthesized_image.jpg',
#  'pose000132_Synthesized_image.jpg',
#  'pose000184_Synthesized_image.jpg',
#  'pose000234_Synthesized_image.jpg',
#  'pose000108_Synthesized_image.jpg',
#  'pose000192_Synthesized_image.jpg',
#  'pose000027_Synthesized_image.jpg',
#  'pose000091_Synthesized_image.jpg',
#  'pose000218_Synthesized_image.jpg',
#  'pose000049_Synthesized_image.jpg',
#  'pose000124_Synthesized_image.jpg',
#  'pose000087_Synthesized_image.jpg',
#  'pose000031_Synthesized_image.jpg',
#  'pose000166_Synthesized_image.jpg',
#  'pose000065_Synthesized_image.jpg',
#  'pose000102_Synthesized_image.jpg',
#  'pose000001_Synthesized_image.jpg',
#  'pose000079_Synthesized_image.jpg',
#  'pose000114_Synthesized_image.jpg',
#  'pose000170_Synthesized_image.jpg',
#  'pose000246_Synthesized_image.jpg',
#  'pose000228_Synthesized_image.jpg',
#  'pose000017_Synthesized_image.jpg',
#  'pose000073_Synthesized_image.jpg',
#  'pose000222_Synthesized_image.jpg',
#  'pose000250_Synthesized_image.jpg',
#  'pose000198_Synthesized_image.jpg',
#  'pose000055_Synthesized_image.jpg',
#  'pose000156_Synthesized_image.jpg',
#  'pose000043_Synthesized_image.jpg',
#  'pose000138_Synthesized_image.jpg',
#  'pose000212_Synthesized_image.jpg',
#  'pose000164_Synthesized_image.jpg',
#  'pose000067_Synthesized_image.jpg',
#  'pose000236_Synthesized_image.jpg',
#  'pose000204_Synthesized_image.jpg',
#  'pose000140_Synthesized_image.jpg',
#  'pose000069_Synthesized_image.jpg',
#  'pose000075_Synthesized_image.jpg',
#  'pose000081_Synthesized_image.jpg',
#  'pose000059_Synthesized_image.jpg',
#  'pose000063_Synthesized_image.jpg',
#  'pose000160_Synthesized_image.jpg',
#  'pose000232_Synthesized_image.jpg',
#  'pose000224_Synthesized_image.jpg',
#  'pose000118_Synthesized_image.jpg',
#  'pose000176_Synthesized_image.jpg',
#  'pose000194_Synthesized_image.jpg',
#  'pose000208_Synthesized_image.jpg',
#  'pose000037_Synthesized_image.jpg',
#  'pose000182_Synthesized_image.jpg',
#  'pose000134_Synthesized_image.jpg',
#  'pose000021_Synthesized_image.jpg',
#  'pose000122_Synthesized_image.jpg',
#  'pose000173_Synthesized_image.jpg',
#  'pose000221_Synthesized_image.jpg',
#  'pose000237_Synthesized_image.jpg',
#  'pose000032_Synthesized_image.jpg',
#  'pose000187_Synthesized_image.jpg',
#  'pose000191_Synthesized_image.jpg',
#  'pose000127_Synthesized_image.jpg',
#  'pose000149_Synthesized_image.jpg',
#  'pose000024_Synthesized_image.jpg',
#  'pose000092_Synthesized_image.jpg',
#  'pose000131_Synthesized_image.jpg',
#  'pose000165_Synthesized_image.jpg',
#  'pose000008_Synthesized_image.jpg',
#  'pose000084_Synthesized_image.jpg',
#  'pose000066_Synthesized_image.jpg',
#  'pose000103_Synthesized_image.jpg',
#  'pose000054_Synthesized_image.jpg',
#  'pose000115_Synthesized_image.jpg',
#  'pose000016_Synthesized_image.jpg',
#  'pose000157_Synthesized_image.jpg',
#  'pose000205_Synthesized_image.jpg',
#  'pose000199_Synthesized_image.jpg',
#  'pose000139_Synthesized_image.jpg',
#  'pose000078_Synthesized_image.jpg',
#  'pose000229_Synthesized_image.jpg',
#  'pose000247_Synthesized_image.jpg',
#  'pose000213_Synthesized_image.jpg',
#  'pose000141_Synthesized_image.jpg',
#  'pose000095_Synthesized_image.jpg',
#  'pose000120_Synthesized_image.jpg',
#  'pose000196_Synthesized_image.jpg',
#  'pose000158_Synthesized_image.jpg',
#  'pose000136_Synthesized_image.jpg',
#  'pose000083_Synthesized_image.jpg',
#  'pose000035_Synthesized_image.jpg',
#  'pose000180_Synthesized_image.jpg',
#  'pose000045_Synthesized_image.jpg',
#  'pose000214_Synthesized_image.jpg',
#  'pose000019_Synthesized_image.jpg',
#  'pose000077_Synthesized_image.jpg',
#  'pose000248_Synthesized_image.jpg',
#  'pose000226_Synthesized_image.jpg',
#  'pose000174_Synthesized_image.jpg',
#  'pose000162_Synthesized_image.jpg',
#  'pose000023_Synthesized_image.jpg',
#  'pose000061_Synthesized_image.jpg',
#  'pose000042_Synthesized_image.jpg',
#  'pose000230_Synthesized_image.jpg',
#  'pose000146_Synthesized_image.jpg',
#  'pose000128_Synthesized_image.jpg',
#  'pose000112_Synthesized_image.jpg',
#  'pose000238_Synthesized_image.jpg',
#  'pose000240_Synthesized_image.jpg',
#  'pose000188_Synthesized_image.jpg',
#  'pose000202_Synthesized_image.jpg',
#  'pose000011_Synthesized_image.jpg',
#  'pose000053_Synthesized_image.jpg',
#  'pose000104_Synthesized_image.jpg',
#  'pose000150_Synthesized_image.jpg',
#  'pose000007_Synthesized_image.jpg',
#  'pose000004_Synthesized_image.jpg',
#  'pose000227_Synthesized_image.jpg',
#  'pose000018_Synthesized_image.jpg',
#  'pose000111_Synthesized_image.jpg',
#  'pose000243_Synthesized_image.jpg',
#  'pose000217_Synthesized_image.jpg',
#  'pose000145_Synthesized_image.jpg',
#  'pose000225_Synthesized_image.jpg',
#  'pose000028_Synthesized_image.jpg',
#  'pose000088_Synthesized_image.jpg',
#  'pose000050_Synthesized_image.jpg',
#  'pose000046_Synthesized_image.jpg',
#  'pose000153_Synthesized_image.jpg',
#  'pose000201_Synthesized_image.jpg',
#  'pose000177_Synthesized_image.jpg',
#  'pose000119_Synthesized_image.jpg',
#  'pose000161_Synthesized_image.jpg',
#  'pose000233_Synthesized_image.jpg',
#  'pose000195_Synthesized_image.jpg',
#  'pose000074_Synthesized_image.jpg',
#  'pose000096_Synthesized_image.jpg',
#  'pose000020_Synthesized_image.jpg',
#  'pose000123_Synthesized_image.jpg',
#  'pose000080_Synthesized_image.jpg',
#  'pose000036_Synthesized_image.jpg',
#  'pose000062_Synthesized_image.jpg',
#  'pose000058_Synthesized_image.jpg',
#  'pose000135_Synthesized_image.jpg',
#  'pose000219_Synthesized_image.jpg',
#  'pose000193_Synthesized_image.jpg',
#  'pose000125_Synthesized_image.jpg',
#  'pose000026_Synthesized_image.jpg',
#  'pose000090_Synthesized_image.jpg',
#  'pose000209_Synthesized_image.jpg',
#  'pose000048_Synthesized_image.jpg',
#  'pose000133_Synthesized_image.jpg',
#  'pose000183_Synthesized_image.jpg',
#  'pose000185_Synthesized_image.jpg',
#  'pose000086_Synthesized_image.jpg',
#  'pose000056_Synthesized_image.jpg',
#  'pose000038_Synthesized_image.jpg',
#  'pose000235_Synthesized_image.jpg',
#  'pose000109_Synthesized_image.jpg',
#  'pose000223_Synthesized_image.jpg',
#  'pose000171_Synthesized_image.jpg',
#  'pose000167_Synthesized_image.jpg',
#  'pose000064_Synthesized_image.jpg',
#  'pose000030_Synthesized_image.jpg',
#  'pose000072_Synthesized_image.jpg',
#  'pose000207_Synthesized_image.jpg',
#  'pose000155_Synthesized_image.jpg',
#  'pose000179_Synthesized_image.jpg',
#  'pose000040_Synthesized_image.jpg',
#  'pose000002_Synthesized_image.jpg',
#  'pose000014_Synthesized_image.jpg',
#  'pose000245_Synthesized_image.jpg',
#  'pose000101_Synthesized_image.jpg',
#  'pose000098_Synthesized_image.jpg',
#  'pose000117_Synthesized_image.jpg',
#  'pose000143_Synthesized_image.jpg',
#  'pose000211_Synthesized_image.jpg',
#  'pose000070_Synthesized_image.jpg',
#  'pose000151_Synthesized_image.jpg',
#  'pose000068_Synthesized_image.jpg',
#  'pose000010_Synthesized_image.jpg',
#  'pose000105_Synthesized_image.jpg',
#  'pose000215_Synthesized_image.jpg',
#  'pose000147_Synthesized_image.jpg',
#  'pose000129_Synthesized_image.jpg',
#  'pose000044_Synthesized_image.jpg',
#  'pose000239_Synthesized_image.jpg',
#  'pose000203_Synthesized_image.jpg',
#  'pose000189_Synthesized_image.jpg',
#  'pose000052_Synthesized_image.jpg',
#  'pose000006_Synthesized_image.jpg',
#  'pose000241_Synthesized_image.jpg',
#  'pose000159_Synthesized_image.jpg',
#  'pose000137_Synthesized_image.jpg',
#  'pose000022_Synthesized_image.jpg',
#  'pose000082_Synthesized_image.jpg',
#  'pose000094_Synthesized_image.jpg',
#  'pose000181_Synthesized_image.jpg',
#  'pose000197_Synthesized_image.jpg',
#  'pose000034_Synthesized_image.jpg',
#  'pose000113_Synthesized_image.jpg',
#  'pose000249_Synthesized_image.jpg',
#  'pose000175_Synthesized_image.jpg',
#  'pose000121_Synthesized_image.jpg',
#  'pose000107_Synthesized_image.jpg',
#  'pose000012_Synthesized_image.jpg',
#  'pose000169_Synthesized_image.jpg',
#  'pose000231_Synthesized_image.jpg',
#  'pose000076_Synthesized_image.jpg',
#  'pose000163_Synthesized_image.jpg',
#  'pose000060_Synthesized_image.jpg']

# %% [markdown]
# # Sorting the files

# %%
files.sort(key = lambda x: x[5:10])
files.sort()

# %%
files
# Out:
# ['pose000001_Synthesized_image.jpg',
#  'pose000002_Synthesized_image.jpg',
#  'pose000003_Synthesized_image.jpg',
#  'pose000004_Synthesized_image.jpg',
#  'pose000005_Synthesized_image.jpg',
#  'pose000006_Synthesized_image.jpg',
#  'pose000007_Synthesized_image.jpg',
#  'pose000008_Synthesized_image.jpg',
#  'pose000009_Synthesized_image.jpg',
#  'pose000010_Synthesized_image.jpg',
#  'pose000011_Synthesized_image.jpg',
#  'pose000012_Synthesized_image.jpg',
#  'pose000013_Synthesized_image.jpg',
#  'pose000014_Synthesized_image.jpg',
#  'pose000015_Synthesized_image.jpg',
#  'pose000016_Synthesized_image.jpg',
#  'pose000017_Synthesized_image.jpg',
#  'pose000018_Synthesized_image.jpg',
#  'pose000019_Synthesized_image.jpg',
#  'pose000020_Synthesized_image.jpg',
#  'pose000021_Synthesized_image.jpg',
#  'pose000022_Synthesized_image.jpg',
#  'pose000023_Synthesized_image.jpg',
#  'pose000024_Synthesized_image.jpg',
#  'pose000025_Synthesized_image.jpg',
#  'pose000026_Synthesized_image.jpg',
#  'pose000027_Synthesized_image.jpg',
#  'pose000028_Synthesized_image.jpg',
#  'pose000029_Synthesized_image.jpg',
#  'pose000030_Synthesized_image.jpg',
#  'pose000031_Synthesized_image.jpg',
#  'pose000032_Synthesized_image.jpg',
#  'pose000033_Synthesized_image.jpg',
#  'pose000034_Synthesized_image.jpg',
#  'pose000035_Synthesized_image.jpg',
#  'pose000036_Synthesized_image.jpg',
#  'pose000037_Synthesized_image.jpg',
#  'pose000038_Synthesized_image.jpg',
#  'pose000039_Synthesized_image.jpg',
#  'pose000040_Synthesized_image.jpg',
#  'pose000041_Synthesized_image.jpg',
#  'pose000042_Synthesized_image.jpg',
#  'pose000043_Synthesized_image.jpg',
#  'pose000044_Synthesized_image.jpg',
#  'pose000045_Synthesized_image.jpg',
#  'pose000046_Synthesized_image.jpg',
#  'pose000047_Synthesized_image.jpg',
#  'pose000048_Synthesized_image.jpg',
#  'pose000049_Synthesized_image.jpg',
#  'pose000050_Synthesized_image.jpg',
#  'pose000051_Synthesized_image.jpg',
#  'pose000052_Synthesized_image.jpg',
#  'pose000053_Synthesized_image.jpg',
#  'pose000054_Synthesized_image.jpg',
#  'pose000055_Synthesized_image.jpg',
#  'pose000056_Synthesized_image.jpg',
#  'pose000057_Synthesized_image.jpg',
#  'pose000058_Synthesized_image.jpg',
#  'pose000059_Synthesized_image.jpg',
#  'pose000060_Synthesized_image.jpg',
#  'pose000061_Synthesized_image.jpg',
#  'pose000062_Synthesized_image.jpg',
#  'pose000063_Synthesized_image.jpg',
#  'pose000064_Synthesized_image.jpg',
#  'pose000065_Synthesized_image.jpg',
#  'pose000066_Synthesized_image.jpg',
#  'pose000067_Synthesized_image.jpg',
#  'pose000068_Synthesized_image.jpg',
#  'pose000069_Synthesized_image.jpg',
#  'pose000070_Synthesized_image.jpg',
#  'pose000071_Synthesized_image.jpg',
#  'pose000072_Synthesized_image.jpg',
#  'pose000073_Synthesized_image.jpg',
#  'pose000074_Synthesized_image.jpg',
#  'pose000075_Synthesized_image.jpg',
#  'pose000076_Synthesized_image.jpg',
#  'pose000077_Synthesized_image.jpg',
#  'pose000078_Synthesized_image.jpg',
#  'pose000079_Synthesized_image.jpg',
#  'pose000080_Synthesized_image.jpg',
#  'pose000081_Synthesized_image.jpg',
#  'pose000082_Synthesized_image.jpg',
#  'pose000083_Synthesized_image.jpg',
#  'pose000084_Synthesized_image.jpg',
#  'pose000085_Synthesized_image.jpg',
#  'pose000086_Synthesized_image.jpg',
#  'pose000087_Synthesized_image.jpg',
#  'pose000088_Synthesized_image.jpg',
#  'pose000089_Synthesized_image.jpg',
#  'pose000090_Synthesized_image.jpg',
#  'pose000091_Synthesized_image.jpg',
#  'pose000092_Synthesized_image.jpg',
#  'pose000093_Synthesized_image.jpg',
#  'pose000094_Synthesized_image.jpg',
#  'pose000095_Synthesized_image.jpg',
#  'pose000096_Synthesized_image.jpg',
#  'pose000097_Synthesized_image.jpg',
#  'pose000098_Synthesized_image.jpg',
#  'pose000099_Synthesized_image.jpg',
#  'pose000100_Synthesized_image.jpg',
#  'pose000101_Synthesized_image.jpg',
#  'pose000102_Synthesized_image.jpg',
#  'pose000103_Synthesized_image.jpg',
#  'pose000104_Synthesized_image.jpg',
#  'pose000105_Synthesized_image.jpg',
#  'pose000106_Synthesized_image.jpg',
#  'pose000107_Synthesized_image.jpg',
#  'pose000108_Synthesized_image.jpg',
#  'pose000109_Synthesized_image.jpg',
#  'pose000110_Synthesized_image.jpg',
#  'pose000111_Synthesized_image.jpg',
#  'pose000112_Synthesized_image.jpg',
#  'pose000113_Synthesized_image.jpg',
#  'pose000114_Synthesized_image.jpg',
#  'pose000115_Synthesized_image.jpg',
#  'pose000116_Synthesized_image.jpg',
#  'pose000117_Synthesized_image.jpg',
#  'pose000118_Synthesized_image.jpg',
#  'pose000119_Synthesized_image.jpg',
#  'pose000120_Synthesized_image.jpg',
#  'pose000121_Synthesized_image.jpg',
#  'pose000122_Synthesized_image.jpg',
#  'pose000123_Synthesized_image.jpg',
#  'pose000124_Synthesized_image.jpg',
#  'pose000125_Synthesized_image.jpg',
#  'pose000126_Synthesized_image.jpg',
#  'pose000127_Synthesized_image.jpg',
#  'pose000128_Synthesized_image.jpg',
#  'pose000129_Synthesized_image.jpg',
#  'pose000130_Synthesized_image.jpg',
#  'pose000131_Synthesized_image.jpg',
#  'pose000132_Synthesized_image.jpg',
#  'pose000133_Synthesized_image.jpg',
#  'pose000134_Synthesized_image.jpg',
#  'pose000135_Synthesized_image.jpg',
#  'pose000136_Synthesized_image.jpg',
#  'pose000137_Synthesized_image.jpg',
#  'pose000138_Synthesized_image.jpg',
#  'pose000139_Synthesized_image.jpg',
#  'pose000140_Synthesized_image.jpg',
#  'pose000141_Synthesized_image.jpg',
#  'pose000142_Synthesized_image.jpg',
#  'pose000143_Synthesized_image.jpg',
#  'pose000144_Synthesized_image.jpg',
#  'pose000145_Synthesized_image.jpg',
#  'pose000146_Synthesized_image.jpg',
#  'pose000147_Synthesized_image.jpg',
#  'pose000148_Synthesized_image.jpg',
#  'pose000149_Synthesized_image.jpg',
#  'pose000150_Synthesized_image.jpg',
#  'pose000151_Synthesized_image.jpg',
#  'pose000152_Synthesized_image.jpg',
#  'pose000153_Synthesized_image.jpg',
#  'pose000154_Synthesized_image.jpg',
#  'pose000155_Synthesized_image.jpg',
#  'pose000156_Synthesized_image.jpg',
#  'pose000157_Synthesized_image.jpg',
#  'pose000158_Synthesized_image.jpg',
#  'pose000159_Synthesized_image.jpg',
#  'pose000160_Synthesized_image.jpg',
#  'pose000161_Synthesized_image.jpg',
#  'pose000162_Synthesized_image.jpg',
#  'pose000163_Synthesized_image.jpg',
#  'pose000164_Synthesized_image.jpg',
#  'pose000165_Synthesized_image.jpg',
#  'pose000166_Synthesized_image.jpg',
#  'pose000167_Synthesized_image.jpg',
#  'pose000168_Synthesized_image.jpg',
#  'pose000169_Synthesized_image.jpg',
#  'pose000170_Synthesized_image.jpg',
#  'pose000171_Synthesized_image.jpg',
#  'pose000172_Synthesized_image.jpg',
#  'pose000173_Synthesized_image.jpg',
#  'pose000174_Synthesized_image.jpg',
#  'pose000175_Synthesized_image.jpg',
#  'pose000176_Synthesized_image.jpg',
#  'pose000177_Synthesized_image.jpg',
#  'pose000178_Synthesized_image.jpg',
#  'pose000179_Synthesized_image.jpg',
#  'pose000180_Synthesized_image.jpg',
#  'pose000181_Synthesized_image.jpg',
#  'pose000182_Synthesized_image.jpg',
#  'pose000183_Synthesized_image.jpg',
#  'pose000184_Synthesized_image.jpg',
#  'pose000185_Synthesized_image.jpg',
#  'pose000186_Synthesized_image.jpg',
#  'pose000187_Synthesized_image.jpg',
#  'pose000188_Synthesized_image.jpg',
#  'pose000189_Synthesized_image.jpg',
#  'pose000190_Synthesized_image.jpg',
#  'pose000191_Synthesized_image.jpg',
#  'pose000192_Synthesized_image.jpg',
#  'pose000193_Synthesized_image.jpg',
#  'pose000194_Synthesized_image.jpg',
#  'pose000195_Synthesized_image.jpg',
#  'pose000196_Synthesized_image.jpg',
#  'pose000197_Synthesized_image.jpg',
#  'pose000198_Synthesized_image.jpg',
#  'pose000199_Synthesized_image.jpg',
#  'pose000200_Synthesized_image.jpg',
#  'pose000201_Synthesized_image.jpg',
#  'pose000202_Synthesized_image.jpg',
#  'pose000203_Synthesized_image.jpg',
#  'pose000204_Synthesized_image.jpg',
#  'pose000205_Synthesized_image.jpg',
#  'pose000206_Synthesized_image.jpg',
#  'pose000207_Synthesized_image.jpg',
#  'pose000208_Synthesized_image.jpg',
#  'pose000209_Synthesized_image.jpg',
#  'pose000210_Synthesized_image.jpg',
#  'pose000211_Synthesized_image.jpg',
#  'pose000212_Synthesized_image.jpg',
#  'pose000213_Synthesized_image.jpg',
#  'pose000214_Synthesized_image.jpg',
#  'pose000215_Synthesized_image.jpg',
#  'pose000216_Synthesized_image.jpg',
#  'pose000217_Synthesized_image.jpg',
#  'pose000218_Synthesized_image.jpg',
#  'pose000219_Synthesized_image.jpg',
#  'pose000220_Synthesized_image.jpg',
#  'pose000221_Synthesized_image.jpg',
#  'pose000222_Synthesized_image.jpg',
#  'pose000223_Synthesized_image.jpg',
#  'pose000224_Synthesized_image.jpg',
#  'pose000225_Synthesized_image.jpg',
#  'pose000226_Synthesized_image.jpg',
#  'pose000227_Synthesized_image.jpg',
#  'pose000228_Synthesized_image.jpg',
#  'pose000229_Synthesized_image.jpg',
#  'pose000230_Synthesized_image.jpg',
#  'pose000231_Synthesized_image.jpg',
#  'pose000232_Synthesized_image.jpg',
#  'pose000233_Synthesized_image.jpg',
#  'pose000234_Synthesized_image.jpg',
#  'pose000235_Synthesized_image.jpg',
#  'pose000236_Synthesized_image.jpg',
#  'pose000237_Synthesized_image.jpg',
#  'pose000238_Synthesized_image.jpg',
#  'pose000239_Synthesized_image.jpg',
#  'pose000240_Synthesized_image.jpg',
#  'pose000241_Synthesized_image.jpg',
#  'pose000242_Synthesized_image.jpg',
#  'pose000243_Synthesized_image.jpg',
#  'pose000244_Synthesized_image.jpg',
#  'pose000245_Synthesized_image.jpg',
#  'pose000246_Synthesized_image.jpg',
#  'pose000247_Synthesized_image.jpg',
#  'pose000248_Synthesized_image.jpg',
#  'pose000249_Synthesized_image.jpg',
#  'pose000250_Synthesized_image.jpg']

# %%
for i in range(len(files)):
    filename = pathIn + files[i]
    
    #reading each files
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    
    #inserting the frames into an image array
    frame_array.append(img)

# %%
# fps value is same as of the target video
fps = 25

# %%
out = cv2.VideoWriter(pathOut,cv2.VideoWriter_fourcc(*'DIVX'), fps, size)

# %% [markdown]
# # Puts all the frames into a video

# %%
for i in range(len(frame_array)):
    # writing to a image array
    out.write(frame_array[i])
out.release()
